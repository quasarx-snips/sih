# %% [markdown]
# <a href="https://colab.research.google.com/github/quasarx-snips/sih/blob/main/neural_models/g1brain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install onnx onnxscript
# Out:
# Collecting onnx
#   Downloading onnx-1.22.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Collecting onnxscript
#   Downloading onnxscript-0.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.13/dist-packages (from onnx) (2.1.3)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.13/dist-packages (from onnx) (5.29.6)
# Requirement already satisfied: typing_extensions>=4.15.0 in /usr/local/lib/python3.13/dist-packages (from onnx) (4.16.0)
# Requirement already satisfied: ml_dtypes>=0.5.4 in /usr/local/lib/python3.13/dist-packages (from onnx) (0.6.0)
# Collecting onnx_ir<2,>=0.1.16 (from onnxscript)
#   Downloading onnx_ir-1.0.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from onnxscript) (26.3)
# Requirement already satisfied: sympy>=1.13 in /usr/local/lib/python3.13/dist-packages (from onnx_ir<2,>=0.1.16->onnxscript) (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13->onnx_ir<2,>=0.1.16->onnxscript) (1.3.0)
# Downloading onnx-1.22.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (19.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 65.1 MB/s eta 0:00:00
# Downloading onnxscript-0.7.1-py3-none-any.whl (721 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.0/722.0 kB 30.4 MB/s eta 0:00:00
# Downloading onnx_ir-1.0.0-py3-none-any.whl (185 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.8/185.8 kB 10.9 MB/s eta 0:00:00
# Installing collected packages: onnx, onnx_ir, onnxscript
# Successfully installed onnx-1.22.0 onnx_ir-1.0.0 onnxscript-0.7.1

# %%
import os, torch, timm, copy
import numpy as np
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset
from torchvision import transforms as T
from torchvision.datasets import ImageFolder
from sklearn.model_selection import StratifiedKFold
from torch.optim.lr_scheduler import CosineAnnealingLR


# 1. Device Setup
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Running Engine on: {device}")

# 2. Path to 100 Images
data_dir = '/content/drive/MyDrive/OrbitalTrust_Data'

# 3. Augmentations (Satellite Invariance)
train_transform = T.Compose([
    T.Resize((256, 256)),
    T.RandomHorizontalFlip(p=0.5),
    T.RandomVerticalFlip(p=0.5),
    T.RandomRotation(degrees=(0, 360)),
    T.ColorJitter(brightness=0.15, contrast=0.15),
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

eval_transform = T.Compose([
    T.Resize((256, 256)),
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load Base Datasets
dataset_full = ImageFolder(root=data_dir)
targets = [label for _, label in dataset_full.samples]
print(f"Loaded {len(dataset_full)} images from Drive. Mapping: {dataset_full.class_to_idx}")

# 4. Stratified 5-Fold Setup
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

best_overall_acc = 0.0
best_model_weights = None

print("\nStarting 5-Fold Stratified Cross Validation...")
print("=" * 55)

for fold, (train_idx, val_idx) in enumerate(skf.split(np.zeros(len(targets)), targets)):
    print(f"\n--- FOLD {fold + 1}/5 ---")

    # Create Subsets with independent transforms
    train_set = Subset(ImageFolder(root=data_dir, transform=train_transform), train_idx)
    val_set = Subset(ImageFolder(root=data_dir, transform=eval_transform), val_idx)

    train_loader = DataLoader(train_set, batch_size=8, shuffle=True)
    val_loader = DataLoader(val_set, batch_size=8, shuffle=False)

    # Model Setup
    model = timm.create_model('efficientnet_b0', pretrained=True, drop_rate=0.3, num_classes=2).to(device)
    criterion = nn.CrossEntropyLoss(label_smoothing=0.05)
    optimizer = optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-2)
    scheduler = CosineAnnealingLR(optimizer, T_max=15)

    fold_best_acc = 0.0

    for epoch in range(15):
        # Training Phase
        model.train()
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

        scheduler.step()

        # Validation Phase
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                _, preds = torch.max(outputs, 1)
                correct += torch.sum(preds == labels.data)
                total += labels.size(0)

        val_acc = (correct.double() / total).item()

        if val_acc > fold_best_acc:
            fold_best_acc = val_acc
            if fold_best_acc > best_overall_acc:
                best_overall_acc = fold_best_acc
                best_model_weights = copy.deepcopy(model.state_dict())

    print(f"Fold {fold + 1} Best Validation Accuracy: {fold_best_acc * 100:.2f}%")

print("=" * 55)
print(f"CROSS VALIDATION COMPLETE | Peak Accuracy: {best_overall_acc * 100:.2f}%")

# Save Best Model Weights
final_model = timm.create_model('efficientnet_b0', pretrained=False, num_classes=2)
final_model.load_state_dict(best_model_weights)
final_model.to(device)
torch.save(final_model.state_dict(), "orbitaltrust_brain.pth")
print("\nBest Model saved as: orbitaltrust_brain.pth")

# Export to ONNX
final_model.eval()
dummy = torch.randn(1, 3, 256, 256).to(device)
torch.onnx.export(
    final_model,
    dummy,
    "orbitaltrust_brain.onnx",
    input_names=['input'],
    output_names=['output'],
    dynamic_axes={'input': {0: 'batch_size'}, 'output': {0: 'batch_size'}}
)
print("ONNX exported as: orbitaltrust_brain.onnx")
# Out:
# Running Engine on: cuda
# Loaded 100 images from Drive. Mapping: {'fake': 0, 'real': 1}
#
# Starting 5-Fold Stratified Cross Validation...
# =======================================================
#
# --- FOLD 1/5 ---
# Fold 1 Best Validation Accuracy: 85.00%
#
# --- FOLD 2/5 ---
# Fold 2 Best Validation Accuracy: 70.00%
#
# --- FOLD 3/5 ---
# Fold 3 Best Validation Accuracy: 60.00%
#
# --- FOLD 4/5 ---
# Fold 4 Best Validation Accuracy: 80.00%
#
# --- FOLD 5/5 ---
# Fold 5 Best Validation Accuracy: 90.00%
# =======================================================
# CROSS VALIDATION COMPLETE | Peak Accuracy: 90.00%
#
# Best Model saved as: orbitaltrust_brain.pth
# /tmp/ipykernel_3495/3588633013.py:116: UserWarning: # 'dynamic_axes' is not recommended when dynamo=True, and may lead to 'torch._dynamo.exc.UserError: Constraints violated.' Supply the 'dynamic_shapes' argument instead if export is unsuccessful.
#   torch.onnx.export(
# [torch.onnx] Obtain model graph for `EfficientNet([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `EfficientNet([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decompositions...
# /usr/lib/python3.13/copyreg.py:99: FutureWarning: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
#   return cls.__new__(cls, *args)
# [torch.onnx] Run decompositions... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
# [torch.onnx] Optimize the ONNX graph...
# [torch.onnx] Optimize the ONNX graph... ✅
# ONNX exported as: orbitaltrust_brain.onnx

# %%
import torch
import timm
from PIL import Image
import torchvision.transforms as T
import torch.nn.functional as F
import matplotlib.pyplot as plt

# 1. Device Setup & Load 90% Model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = timm.create_model('efficientnet_b0', pretrained=False, num_classes=2)
model.load_state_dict(torch.load("orbitaltrust_brain.pth", map_location=device))
model = model.to(device)
model.eval()

class_names = ['FAKE', 'REAL']  # ImageFolder default mapping

# 2. Preprocessing Transform
transform = T.Compose([
    T.Resize((256, 256)),
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# 3. Single Image Testing Function
def test_single_image(image_path):
    try:
        raw_img = Image.open(image_path).convert('RGB')
        input_tensor = transform(raw_img).unsqueeze(0).to(device)

        with torch.no_grad():
            outputs = model(input_tensor)
            probs = F.softmax(outputs, dim=1)[0]
            pred_idx = torch.argmax(probs).item()

        verdict = class_names[pred_idx]
        fake_prob = probs[0].item() * 100
        real_prob = probs[1].item() * 100

        # Display Image with Color-Coded Verdict
        plt.figure(figsize=(6, 6))
        plt.imshow(raw_img)
        plt.axis('off')

        title_color = 'green' if verdict == 'REAL' else 'red'
        plt.title(f"PREDICTION: {verdict}\nReal: {real_prob:.2f}% | Fake: {fake_prob:.2f}%",
                  color=title_color, fontsize=14, fontweight='bold')
        plt.show()

    except FileNotFoundError:
        print(f"File '{image_path}' not found! Check the filename in Colab files sidebar.")
test_single_image("urban_1.jpg")
